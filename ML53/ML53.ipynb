# %%
import pandas as pd

df = pd.read_csv("employees.csv", parse_dates=["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-12-23 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-12-23 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-12-23 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-12-23 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-12-23 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df["Gender"] == "Male"

df[df["Gender"] == "Male"].head()
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2018-12-23 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2018-12-23 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2018-12-23 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2018-12-23 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2018-12-23 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
df["Team"] == "Finance"

df[df["Team"] == "Finance"].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2018-12-23 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-12-23 13:00:00  138705    9.340
# 7         NaN  Female 2015-07-20 2018-12-23 10:43:00   45906   11.598
# 14   Kimberly  Female 1999-01-14 2018-12-23 07:13:00   41426   14.543
# 46      Bruce    Male 2009-11-28 2018-12-23 22:47:00  114796    6.796
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                True  Finance
# 14               True  Finance
# 46              False  Finance

# %%
mask = df["Team"] == "Finance"
df[mask]
df[mask].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2018-12-23 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-12-23 13:00:00  138705    9.340
# 7         NaN  Female 2015-07-20 2018-12-23 10:43:00   45906   11.598
# 14   Kimberly  Female 1999-01-14 2018-12-23 07:13:00   41426   14.543
# 46      Bruce    Male 2009-11-28 2018-12-23 22:47:00  114796    6.796
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                True  Finance
# 14               True  Finance
# 46              False  Finance

# %%
df[df["Senior Management"]].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-12-23 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-12-23 06:53:00   61933    4.170
# 3      Jerry    Male 2005-03-04 2018-12-23 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-12-23 16:47:00  101004    1.389
# 6       Ruby  Female 1987-08-17 2018-12-23 16:20:00   65476   10.012
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 6               True          Product

# %%
df[df["Team"] != "Marketing"]
df[df["Team"] != "Marketing"].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1     Thomas    Male 1996-03-31 2018-12-23 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-12-23 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-12-23 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-12-23 16:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18 2018-12-23 01:35:00  115163   10.125
#
#    Senior Management             Team
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
df["Salary"] > 110000

df[df["Salary"] > 110000].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2018-12-23 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-12-23 13:00:00  138705    9.340
# 5      Dennis    Male 1987-04-18 2018-12-23 01:35:00  115163   10.125
# 9     Frances  Female 2002-08-08 2018-12-23 06:51:00  139852    7.524
# 12    Brandon    Male 1980-12-01 2018-12-23 01:08:00  112807   17.492
#
#     Senior Management                  Team
# 2               False               Finance
# 3                True               Finance
# 5               False                 Legal
# 9                True  Business Development
# 12               True       Human Resources

# %%
df["Bonus %"] < 1.5

df[df["Bonus %"] < 1.5].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2018-12-23 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2018-12-23 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2018-12-23 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2018-12-23 20:13:00  107391    1.260
# 175     Willie    Male 1998-02-17 2018-12-23 20:20:00  146651    1.451
#
#      Senior Management             Team
# 4                 True  Client Services
# 15               False          Product
# 58                True      Engineering
# 77                True        Marketing
# 175               True      Engineering

# %%
mask = df["Start Date"] <= "1985-01-01"

df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2018-12-23 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2018-12-23 01:08:00  112807   17.492
# 18       Diana  Female 1981-10-
# 843     Louise  Female 1982-02-26 2018-12-23 01:03:00  106362    8.965
# 845     Brenda  Female 1981-01-03 2018-12-23 18:01:00  131131   11.682
# 847     Nicole     NaN 1981-05-02 2018-12-23 12:03:00   41449    4.707
# 848      Bobby    Male 1984-06-05 2018-12-23 07:40:00   93368    2.880
# 860    Phillip    Male 1984-10-07 2018-12-23 11:05:00   36837   14.660
# 862     Ronald    Male 1983-05-25 2018-12-23 10:05:00   50426   18.536
# 863    Phillip    Male 1984-05-15 2018-12-23 06:15:00  134120    6.842
# 877        NaN    Male 1980-09-05 2018-12-23 07:36:00  114896   13.823
# 881       Ruby  Female 1980-01-28 2018-12-23 23:08:00  142868    6.318
# 903    Heather  Female 1983-07-29 2018-12-23 10:48:00   47605   14.955
# 915       Todd    Male 1983-01-04 2018-12-23 12:34:00  115566    6.716
# 950      Paula  Female 1983-05-21 2018-12-23 11:42:00   58423   10.833
# 954        Joe    Male 1980-01-19 2018-12-23 16:06:00  119667    1.148
# 957    Jeffrey    Male 1984-02-03 2018-12-23 13:26:00   70990   15.901
# 964      Bruce    Male 1980-05-07 2018-12-23 20:00:00   35802   12.391
# 978       Sean    Male 1983-01-17 2018-12-23 14:23:00   66146   11.178
# 982       Rose  Female 1982-04-06 2018-12-23 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2018-12-23 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2018-12-23 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2018-12-23 07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31 2018-12-23 06:30:00   42392   19.675
#
#      Senior Management                  Team
# 10                True                   NaN
# 12                True       Human Resources
# 18               False       Client Services
# 28                True       Client Services
# 37                True       Client Services
# 43                True             Marketing
# 45                True                 Sales
# 49               False                 Sales
# 78                True                 Sales
# 82                True       Client Services
# 94               False                 Legal
# 115              False               Product
# 124               True               Product
# 126               True       Human Resources
# 130               True       Human Resources
# 140              False             Marketing
# 144              False                 Sales
# 154               True               Product
# 159              False             Marketing
# 185               True                 Legal
# 202               True                 Sales
# 213               True           Engineering
# 234               True       Client Services
# 238              False                 Legal
# 240              False          Distribution
# 241              False               Finance
# 246               True       Human Resources
# 264               True       Human Resources
# 268               True               Finance
# 272              False               Product
# ..                 ...                   ...
# 784              False                 Sales
# 785               True             Marketing
# 791              False                 Legal
# 797              False           Engineering
# 798               True             Marketing
# 808              False           Engineering
# 818               True          Distribution
# 821               True          Distribution
# 834               True  Business Development
# 843              False                 Sales
# 845              False       Client Services
# 847              False               Finance
# 848               True               Product
# 860              False             Marketing
# 862               True                 Sales
# 863              False       Human Resources
# 877               True       Client Services
# 881              False             Marketing
# 903               True       Human Resources
# 915               True       Client Services
# 950              False  Business Development
# 954               True               Finance
# 957               True                 Sales
# 964               True                 Sales
# 978              False       Human Resources
# 982               True       Human Resources
# 983              False           Engineering
# 985              False                 Legal
# 986              False             Marketing
# 996              False               Finance
#
# [133 rows x 8 columns]
