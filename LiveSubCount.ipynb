# %%
import urllib.request
import json

while True:
    name = "TSeries"
    key = "Enter Your API Key"
    
    data = urllib.request.urlopen("https://www.googleapis.com/youtube/v3/channels?part=statistics&forUsername="+name+"&key="+key).read()
    
    subs = json.loads(data)["items"][0]["statistics"]["subscriberCount"]
    
    print(name+" has "+"{:,d}".format(int(subs))+" subscribers!!!")
# Out:
# TSeries has 72,582,533 subscribers!!!
# TSeries has 72,582,533 subscribers!!!
# TSeries has 72,582,534 subscribers!!!
# TSeries has 72,582,536 subscribers!!!
# TSeries has 72,582,538 subscribers!!!
# TSeries has 72,582,538 subscribers!!!
# TSeries has 72,582,537 subscribers!!!
# TSeries has 72,582,539 subscribers!!!
# TSeries has 72,582,539 subscribers!!!
# TSeries has 72,582,544 subscribers!!!
# TSeries has 72,582,545 subscribers!!!
# TSeries has 72,582,547 subscribers!!!
# TSeries has 72,582,547 subscribers!!!
# TSeries has 72,582,549 subscribers!!!
# TSeries has 72,582,549 subscribers!!!
# TSeries has 72,582,549 subscribers!!!
# TSeries has 72,582,549 subscribers!!!
# TSeries has 72,582,550 subscribers!!!
# TSeries has 72,582,528 subscribers!!!
# TSeries has 72,582,552 subscribers!!!
# TSeries has 72,582,553 subscribers!!!
# TSeries has 72,582,555 subscribers!!!
# TSeries has 72,582,537 subscribers!!!
# TSeries has 72,582,557 subscribers!!!
# TSeries has 72,582,564 subscribers!!!
# TSeries has 72,582,565 subscribers!!!
# TSeries has 72,582,566 subscribers!!!
# TSeries has 72,582,563 subscribers!!!
# TSeries has 72,582,567 subscribers!!!
# TSeries has 72,582,569 subscribers!!!
# TSeries has 72,582,570 subscribers!!!
# TSeries has 72,582,571 subscribers!!!
# TSeries has 72,582,567 subscribers!!!
# TSeries has 72,582,572 subscribers!!!
# TSeries has 72,582,576 subscribers!!!
# TSeries has 72,582,551 subscribers!!!
# TSeries has 72,582,576 subscribers!!!
# TSeries has 72,582,556 subscribers!!!
# TSeries has 72,582,574 subscribers!!!
# TSeries has 72,582,575 subscribers!!!
# TSeries has 72,582,576 subscribers!!!
# TSeries has 72,582,577 subscribers!!!
# TSeries has 72,582,583 subscribers!!!
# TSeries has 72,582,585 subscribers!!!
# TSeries has 72,582,585 subscribers!!!
# TSeries has 72,582,588 subscribers!!!
# TSeries has 72,582,586 subscribers!!!
# TSeries has 72,582,586 subscribers!!!
# TSeries has 72,582,591 subscribers!!!
# TSeries has 72,582,594 subscribers!!!
# TSeries has 72,582,593 subscribers!!!
# TSeries has 72,582,594 subscribers!!!
# TSeries has 72,582,594 subscribers!!!
# TSeries has 72,582,594 subscribers!!!
# TSeries has 72,582,594 subscribers!!!
# TSeries has 72,582,594 subscribers!!!
# TSeries has 72,582,578 subscribers!!!
# TSeries has 72,582,596 subscribers!!!
# TSeries has 72,582,596 subscribers!!!
# TSeries has 72,582,594 subscribers!!!
# TSeries has 72,582,601 subscribers!!!
# TSeries has 72,582,601 subscribers!!!
# TSeries has 72,582,601 subscribers!!!
# TSeries has 72,582,603 subscribers!!!
# TSeries has 72,582,601 subscribers!!!
# TSeries has 72,582,606 subscribers!!!
# TSeries has 72,582,611 subscribers!!!
# TSeries has 72,582,611 subscribers!!!
# TSeries has 72,582,611 subscribers!!!
# TSeries has 72,582,605 subscribers!!!
# TSeries has 72,582,610 subscribers!!!
# TSeries has 72,582,610 subscribers!!!
# TSeries has 72,582,610 subscribers!!!
# TSeries has 72,582,609 subscribers!!!
# TSeries has 72,582,609 subscribers!!!
# TSeries has 72,582,611 subscribers!!!
# TSeries has 72,582,630 subscribers!!!
# TSeries has 72,582,638 subscribers!!!
# TSeries has 72,582,638 subscribers!!!
# TSeries has 72,582,638 subscribers!!!
# TSeries has 72,582,640 subscribers!!!
# TSeries has 72,582,640 subscribers!!!
# TSeries has 72,582,612 subscribers!!!
# TSeries has 72,582,645 subscribers!!!
# TSeries has 72,582,646 subscribers!!!
# TSeries has 72,582,647 subscribers!!!
# TSeries has 72,582,647 subscribers!!!
# TSeries has 72,582,646 subscribers!!!
# TSeries has 72,582,650 subscribers!!!
# TSeries has 72,582,651 subscribers!!!
# TSeries has 72,582,651 subscribers!!!
# TSeries has 72,582,652 subscribers!!!
# TSeries has 72,582,652 subscribers!!!
# TSeries has 72,582,654 subscribers!!!
# TSeries has 72,582,654 subscribers!!!
# TSeries has 72,582,661 subscribers!!!
# TSeries has 72,582,660 subscribers!!!
# TSeries has 72,582,661 subscribers!!!
# TSeries has 72,582,663 subscribers!!!
# TSeries has 72,582,662 subscribers!!!
# TSeries has 72,582,664 subscribers!!!
# TSeries has 72,582,665 subscribers!!!
# TSeries has 72,582,665 subscribers!!!
# TSeries has 72,582,665 subscribers!!!
# TSeries has 72,582,668 subscribers!!!
# TSeries has 72,582,666 subscribers!!!
# TSeries has 72,582,670 subscribers!!!
# TSeries has 72,582,670 subscribers!!!
# TSeries has 72,582,670 subscribers!!!
# TSeries has 72,582,671 subscribers!!!
# TSeries has 72,582,670 subscribers!!!
# TSeries has 72,582,671 subscribers!!!
# TSeries has 72,582,662 subscribers!!!
# TSeries has 72,582,674 subscribers!!!
# TSeries has 72,582,673 subscribers!!!
# TSeries has 72,582,673 subscribers!!!
# TSeries has 72,582,672 subscribers!!!
# TSeries has 72,582,674 subscribers!!!
# TSeries has 72,582,674 subscribers!!!
# TSeries has 72,582,674 subscribers!!!
# TSeries has 72,582,675 subscribers!!!
# TSeries has 72,582,683 subscribers!!!
# TSeries has 72,582,683 subscribers!!!
# TSeries has 72,582,683 subscribers!!!
# TSeries has 72,582,682 subscribers!!!
# TSeries has 72,582,685 subscribers!!!
# TSeries has 72,582,685 subscribers!!!
# TSeries has 72,582,686 subscribers!!!
# TSeries has 72,582,686 subscribers!!!
# TSeries has 72,582,685 subscribers!!!
# TSeries has 72,582,688 subscribers!!!
# TSeries has 72,582,689 subscribers!!!
# TSeries has 72,582,689 subscribers!!!
# TSeries has 72,582,690 subscribers!!!
# TSeries has 72,582,691 subscribers!!!
# TSeries has 72,582,691 subscribers!!!
# TSeries has 72,582,691 subscribers!!!
# TSeries has 72,582,695 subscribers!!!
# TSeries has 72,582,695 subscribers!!!
# TSeries has 72,582,696 subscribers!!!
# TSeries has 72,582,697 subscribers!!!
# TSeries has 72,582,698 subscribers!!!
# TSeries has 72,582,700 subscribers!!!
# TSeries has 72,582,701 subscribers!!!
# TSeries has 72,582,701 subscribers!!!
# TSeries has 72,582,704 subscribers!!!
# TSeries has 72,582,706 subscribers!!!
# TSeries has 72,582,706 subscribers!!!
# TSeries has 72,582,703 subscribers!!!
# TSeries has 72,582,711 subscribers!!!
# TSeries has 72,582,711 subscribers!!!
# TSeries has 72,582,713 subscribers!!!
# TSeries has 72,582,712 subscribers!!!
# TSeries has 72,582,712 subscribers!!!
# TSeries has 72,582,718 subscribers!!!
# TSeries has 72,582,719 subscribers!!!
# TSeries has 72,582,722 subscribers!!!
# TSeries has 72,582,724 subscribers!!!
# TSeries has 72,582,728 subscribers!!!
# TSeries has 72,582,730 subscribers!!!
# TSeries has 72,582,731 subscribers!!!
# TSeries has 72,582,732 subscribers!!!
# TSeries has 72,582,732 subscribers!!!
# TSeries has 72,582,735 subscribers!!!
# TSeries has 72,582,737 subscribers!!!
# TSeries has 72,582,735 subscribers!!!
# TSeries has 72,582,737 subscribers!!!
# TSeries has 72,582,743 subscribers!!!
# TSeries has 72,582,746 subscribers!!!
# TSeries has 72,582,747 subscribers!!!
# TSeries has 72,582,747 subscribers!!!
# TSeries has 72,582,747 subscribers!!!
# TSeries has 72,582,747 subscribers!!!
# TSeries has 72,582,748 subscribers!!!
# TSeries has 72,582,748 subscribers!!!
# TSeries has 72,582,756 subscribers!!!
# TSeries has 72,582,756 subscribers!!!
# TSeries has 72,582,762 subscribers!!!
# TSeries has 72,582,761 subscribers!!!
# TSeries has 72,582,761 subscribers!!!
# TSeries has 72,582,763 subscribers!!!
# TSeries has 72,582,764 subscribers!!!
# TSeries has 72,582,765 subscribers!!!
# TSeries has 72,582,763 subscribers!!!
# TSeries has 72,582,769 subscribers!!!
# TSeries has 72,582,770 subscribers!!!
# TSeries has 72,582,771 subscribers!!!
# TSeries has 72,582,771 subscribers!!!
# TSeries has 72,582,770 subscribers!!!
# TSeries has 72,582,774 subscribers!!!
# TSeries has 72,582,772 subscribers!!!
# TSeries has 72,582,776 subscribers!!!
# TSeries has 72,582,778 subscribers!!!
# TSeries has 72,582,779 subscribers!!!
# TSeries has 72,582,764 subscribers!!!
# TSeries has 72,582,779 subscribers!!!
# TSeries has 72,582,768 subscribers!!!
# TSeries has 72,582,780 subscribers!!!
# TSeries has 72,582,781 subscribers!!!
# TSeries has 72,582,781 subscribers!!!
# TSeries has 72,582,780 subscribers!!!
# TSeries has 72,582,788 subscribers!!!
# TSeries has 72,582,788 subscribers!!!
# TSeries has 72,582,792 subscribers!!!
# TSeries has 72,582,793 subscribers!!!
# TSeries has 72,582,793 subscribers!!!
# TSeries has 72,582,775 subscribers!!!
# TSeries has 72,582,795 subscribers!!!
# TSeries has 72,582,795 subscribers!!!
# TSeries has 72,582,795 subscribers!!!
# TSeries has 72,582,803 subscribers!!!
# TSeries has 72,582,803 subscribers!!!
# TSeries has 72,582,804 subscribers!!!
# TSeries has 72,582,801 subscribers!!!
# TSeries has 72,582,802 subscribers!!!
# TSeries has 72,582,802 subscribers!!!
# TSeries has 72,582,807 subscribers!!!
# TSeries has 72,582,810 subscribers!!!
# TSeries has 72,582,814 subscribers!!!
# TSeries has 72,582,817 subscribers!!!
# TSeries has 72,582,815 subscribers!!!
# TSeries has 72,582,815 subscribers!!!
# TSeries has 72,582,805 subscribers!!!
# TSeries has 72,582,803 subscribers!!!
# TSeries has 72,582,822 subscribers!!!
# TSeries has 72,582,824 subscribers!!!
# TSeries has 72,582,824 subscribers!!!
# TSeries has 72,582,824 subscribers!!!
# TSeries has 72,582,824 subscribers!!!
# TSeries has 72,582,829 subscribers!!!
# TSeries has 72,582,829 subscribers!!!
# TSeries has 72,582,829 subscribers!!!
# TSeries has 72,582,829 subscribers!!!
# TSeries has 72,582,828 subscribers!!!
# TSeries has 72,582,831 subscribers!!!
# TSeries has 72,582,831 subscribers!!!
# TSeries has 72,582,829 subscribers!!!
# TSeries has 72,582,831 subscribers!!!
# TSeries has 72,582,833 subscribers!!!
# TSeries has 72,582,834 subscribers!!!
# TSeries has 72,582,835 subscribers!!!
# TSeries has 72,582,835 subscribers!!!
# TSeries has 72,582,836 subscribers!!!
# TSeries has 72,582,838 subscribers!!!
# TSeries has 72,582,841 subscribers!!!
# TSeries has 72,582,842 subscribers!!!
# TSeries has 72,582,843 subscribers!!!
# TSeries has 72,582,844 subscribers!!!
# TSeries has 72,582,839 subscribers!!!
# TSeries has 72,582,839 subscribers!!!
# TSeries has 72,582,839 subscribers!!!
# TSeries has 72,582,847 subscribers!!!
# TSeries has 72,582,847 subscribers!!!
# TSeries has 72,582,849 subscribers!!!
# TSeries has 72,582,849 subscribers!!!
# TSeries has 72,582,847 subscribers!!!
# TSeries has 72,582,851 subscribers!!!
# TSeries has 72,582,852 subscribers!!!
# TSeries has 72,582,852 subscribers!!!
# TSeries has 72,582,853 subscribers!!!
# TSeries has 72,582,854 subscribers!!!
# TSeries has 72,582,856 subscribers!!!
# TSeries has 72,582,859 subscribers!!!
# TSeries has 72,582,860 subscribers!!!
# TSeries has 72,582,846 subscribers!!!
# TSeries has 72,582,864 subscribers!!!
# TSeries has 72,582,866 subscribers!!!
# TSeries has 72,582,865 subscribers!!!
# TSeries has 72,582,869 subscribers!!!
# TSeries has 72,582,850 subscribers!!!
# TSeries has 72,582,864 subscribers!!!
# TSeries has 72,582,872 subscribers!!!
# TSeries has 72,582,851 subscribers!!!
# TSeries has 72,582,875 subscribers!!!
# TSeries has 72,582,877 subscribers!!!
# TSeries has 72,582,872 subscribers!!!
# TSeries has 72,582,866 subscribers!!!
# TSeries has 72,582,882 subscribers!!!
# TSeries has 72,582,886 subscribers!!!
# TSeries has 72,582,883 subscribers!!!
# TSeries has 72,582,883 subscribers!!!
# TSeries has 72,582,887 subscribers!!!
# TSeries has 72,582,890 subscribers!!!
# TSeries has 72,582,891 subscribers!!!
# TSeries has 72,582,873 subscribers!!!
# TSeries has 72,582,899 subscribers!!!
# TSeries has 72,582,901 subscribers!!!
# TSeries has 72,582,901 subscribers!!!
# TSeries has 72,582,903 subscribers!!!
# TSeries has 72,582,874 subscribers!!!
# TSeries has 72,582,876 subscribers!!!
# TSeries has 72,582,883 subscribers!!!
# TSeries has 72,582,883 subscribers!!!
# TSeries has 72,582,914 subscribers!!!
# TSeries has 72,582,914 subscribers!!!
# TSeries has 72,582,913 subscribers!!!
# TSeries has 72,582,914 subscribers!!!
# TSeries has 72,582,914 subscribers!!!
# TSeries has 72,582,915 subscribers!!!
# TSeries has 72,582,917 subscribers!!!
# TSeries has 72,582,920 subscribers!!!
# TSeries has 72,582,920 subscribers!!!
# TSeries has 72,582,921 subscribers!!!
# TSeries has 72,582,920 subscribers!!!
# TSeries has 72,582,924 subscribers!!!
# TSeries has 72,582,925 subscribers!!!
# TSeries has 72,582,926 subscribers!!!
# TSeries has 72,582,923 subscribers!!!
# TSeries has 72,582,923 subscribers!!!
# TSeries has 72,582,916 subscribers!!!
# TSeries has 72,582,931 subscribers!!!
# TSeries has 72,582,936 subscribers!!!
# TSeries has 72,582,937 subscribers!!!
# TSeries has 72,582,939 subscribers!!!
# TSeries has 72,582,940 subscribers!!!
# TSeries has 72,582,940 subscribers!!!
# TSeries has 72,582,943 subscribers!!!
# TSeries has 72,582,943 subscribers!!!
# TSeries has 72,582,941 subscribers!!!
# TSeries has 72,582,941 subscribers!!!
# TSeries has 72,582,945 subscribers!!!
# TSeries has 72,582,942 subscribers!!!
# TSeries has 72,582,942 subscribers!!!
# TSeries has 72,582,947 subscribers!!!
# TSeries has 72,582,948 subscribers!!!
# TSeries has 72,582,950 subscribers!!!
# TSeries has 72,582,948 subscribers!!!
# TSeries has 72,582,948 subscribers!!!
# TSeries has 72,582,951 subscribers!!!
# TSeries has 72,582,951 subscribers!!!
# TSeries has 72,582,961 subscribers!!!
# TSeries has 72,582,960 subscribers!!!
# TSeries has 72,582,943 subscribers!!!
# TSeries has 72,582,962 subscribers!!!
# TSeries has 72,582,962 subscribers!!!
# TSeries has 72,582,962 subscribers!!!
# TSeries has 72,582,962 subscribers!!!
# TSeries has 72,582,963 subscribers!!!
# TSeries has 72,582,963 subscribers!!!
# TSeries has 72,582,964 subscribers!!!
# TSeries has 72,582,965 subscribers!!!
# TSeries has 72,582,967 subscribers!!!
# TSeries has 72,582,967 subscribers!!!
# TSeries has 72,582,971 subscribers!!!
# TSeries has 72,582,967 subscribers!!!
# TSeries has 72,582,967 subscribers!!!
# TSeries has 72,582,967 subscribers!!!
# TSeries has 72,582,972 subscribers!!!
# TSeries has 72,582,972 subscribers!!!
# TSeries has 72,582,972 subscribers!!!
# TSeries has 72,582,975 subscribers!!!
# TSeries has 72,582,975 subscribers!!!
# TSeries has 72,582,978 subscribers!!!
# TSeries has 72,582,973 subscribers!!!
# TSeries has 72,582,973 subscribers!!!
# TSeries has 72,582,980 subscribers!!!
# TSeries has 72,582,980 subscribers!!!
# TSeries has 72,582,979 subscribers!!!
# TSeries has 72,582,985 subscribers!!!
# TSeries has 72,582,985 subscribers!!!
# TSeries has 72,582,986 subscribers!!!
# TSeries has 72,582,985 subscribers!!!
# TSeries has 72,582,987 subscribers!!!
# TSeries has 72,582,987 subscribers!!!
# TSeries has 72,582,987 subscribers!!!
# TSeries has 72,582,991 subscribers!!!
# TSeries has 72,582,996 subscribers!!!
# TSeries has 72,582,993 subscribers!!!
# TSeries has 72,582,997 subscribers!!!
# TSeries has 72,582,998 subscribers!!!
# TSeries has 72,582,995 subscribers!!!
# TSeries has 72,582,998 subscribers!!!
# TSeries has 72,582,998 subscribers!!!
# TSeries has 72,583,002 subscribers!!!
